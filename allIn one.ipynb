# %% [markdown]
# <a href="https://colab.research.google.com/github/lk123niwuebdsvbdVFOY/Pandas/blob/AI/allIn%20one.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('/content/train.csv')
data
# Out:
#        Student_ID  Age  Gender  Degree Branch  CGPA  Internships  Projects  \
# 0            1048   22  Female  B.Tech    ECE  6.29            0         3
# 1           37820   20  Female     BCA    ECE  6.05            1         4
# 2           49668   22    Male     MCA     ME  7.22            1         4
# 3           19467   22    Male     MCA     ME  7.78            2         4
# 4           23094   20  Female  B.Tech     ME  7.63            1         4
# ...           ...  ...     ...     ...    ...   ...          ...       ...
# 44995        9362   20    Male     MCA  Civil  7.84            2         5
# 44996        8940   19  Female    B.Sc     ME  8.28            1         4
# 44997       13097   20  Female    B.Sc  Civil  8.88            0         4
# 44998       12958   24  Female     MCA    ECE  5.90            1         3
# 44999        9565   23  Female  B.Tech     ME  6.28            0         4
#
#        Coding_Skills  Communication_Skills  Aptitude_Test_Score  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45000 entries, 0 to 44999
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Student_ID            45000 non-null  int64
#  1   Age                   45000 non-null  int64
#  2   Gender                45000 non-null  object
#  3   Degree                45000 non-null  object
#  4   Branch                45000 non-null  object
#  5   CGPA                  45000 non-null  float64
#  6   Internships           45000 non-null  int64
#  7   Projects              45000 non-null  int64
#  8   Coding_Skills         45000 non-null  int64
#  9   Communication_Skills  45000 non-null  int64
#  10  Aptitude_Test_Score   45000 non-null  int64
#  11  Soft_Skills_Rating    45000 non-null  int64
#  12  Certifications        45000 non-null  int64
#  13  Backlogs              45000 non-null  int64
#  14  Placement_Status      45000 non-null  object
# ...

# %%
data.describe()
# Out:
#          Student_ID           Age          CGPA   Internships      Projects  \
# count  45000.000000  45000.000000  45000.000000  45000.000000  45000.000000
# mean   24977.962600     20.999333      7.002290      0.774089      3.734222
# std    14425.605704      1.995071      0.993855      0.844750      0.923738
# min        1.000000     18.000000      4.500000      0.000000      1.000000
# 25%    12509.750000     19.000000      6.320000      0.000000      3.000000
# 50%    24957.500000     21.000000      7.000000      1.000000      4.000000
# 75%    37475.250000     23.000000      7.670000      1.000000      4.000000
# max    50000.000000     24.000000      9.800000      3.000000      6.000000
#
#        Coding_Skills  Communication_Skills  Aptitude_Test_Score  \
# count   45000.000000          45000.000000         45000.000000
# mean        5.691800              5.501644            69.385356
# std         1.994674              1.515374            13.909710
# ...

# %%
data.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
data.head(2)
# Out:
#    Student_ID  Age  Gender  Degree Branch  CGPA  Internships  Projects  \
# 0        1048   22  Female  B.Tech    ECE  6.29            0         3
# 1       37820   20  Female     BCA    ECE  6.05            1         4
#
#    Coding_Skills  Communication_Skills  Aptitude_Test_Score  \
# 0              4                     6                   51
# 1              6                     8                   59
#
#    Soft_Skills_Rating  Certifications  Backlogs Placement_Status
# 0                   5               1         3       Not Placed
# 1                   8               2         1       Not Placed

# %%
sns.boxplot(x='Placement_Status',y='Age',hue='Gender',data=data)
plt.xlabel('Placement_Status')
plt.ylabel('Age')
plt.title('Placement_Status vs Age')
plt.grid()
plt.show()

# %%
sns.countplot(x='Placement_Status',hue='Gender',data=data)
plt.xlabel('Placement_Status')
plt.ylabel('Degree')
plt.title('Placement_Status vs Degree')
plt.grid()
plt.show()

# %%
data['Degree'].nunique()
# Out:
# 4

# %%
sns.countplot(x='Placement_Status',hue='Degree',data=data)
plt.xlabel('Placement_Status')
plt.ylabel('Branch')
plt.title('Placement_Status vs 	Branch')
plt.grid()
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 9 (	) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
sns.boxplot(x='Placement_Status',y='Internships',data=data)
plt.xlabel('Placement_Status')
plt.ylabel('Internships')
plt.title('Placement_Status vs Internships')
plt.grid()
plt.show()

# %%
sns.boxplot(x='Placement_Status',y='Projects',data=data)
plt.xlabel('Placement_Status')
plt.ylabel('Projects')
plt.title('Placement_Status vs Projects')
plt.grid()
plt.show()

# %%
sns.boxplot(x='Placement_Status',y='Coding_Skills',data=data)
plt.xlabel('Placement_Status')
plt.ylabel('Coding_Skills')
plt.title('Placement_Status vs Coding_Skills')
plt.grid()
plt.show()

# %%
sns.boxplot(x='Placement_Status',y='Communication_Skills',data=data)
plt.xlabel('Placement_Status')
plt.ylabel('Communication_Skills')
plt.title('Placement_Status vs Communication_Skills')
plt.grid()
plt.show()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45000 entries, 0 to 44999
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Student_ID            45000 non-null  int64
#  1   Age                   45000 non-null  int64
#  2   Gender                45000 non-null  object
#  3   Degree                45000 non-null  object
#  4   Branch                45000 non-null  object
#  5   CGPA                  45000 non-null  float64
#  6   Internships           45000 non-null  int64
#  7   Projects              45000 non-null  int64
#  8   Coding_Skills         45000 non-null  int64
#  9   Communication_Skills  45000 non-null  int64
#  10  Aptitude_Test_Score   45000 non-null  int64
#  11  Soft_Skills_Rating    45000 non-null  int64
#  12  Certifications        45000 non-null  int64
#  13  Backlogs              45000 non-null  int64
#  14  Placement_Status      45000 non-null  object
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data['Degree'] = le.fit_transform(data['Degree'])
data['Branch'] = le.fit_transform(data['Branch'])
data['Placement_Status'] = le.fit_transform(data['Placement_Status'])

# %%
data.columns
# Out:
# Index(['Student_ID', 'Age', 'Gender', 'Degree', 'Branch', 'CGPA',
#        'Internships', 'Projects', 'Coding_Skills', 'Communication_Skills',
#        'Aptitude_Test_Score', 'Soft_Skills_Rating', 'Certifications',
#        'Backlogs', 'Placement_Status'],
#       dtype='object')

# %%
x = data[['Age','Degree', 'Branch', 'CGPA',
       'Internships', 'Projects', 'Coding_Skills', 'Communication_Skills',
       'Aptitude_Test_Score', 'Soft_Skills_Rating', 'Certifications',
       'Backlogs']]
y = data['Placement_Status']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state=23456)

# %%
from sklearn.svm import SVC
svc = SVC(kernel='rbf')
svc.fit(x_train,y_train)
# Out:
# SVC()

# %%
svc_y = svc.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,svc_y))
# Out:
# 0.8720888888888889

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
lr_y = svc.predict(x_test)

# %%
accuracy_score(y_test,lr_y)
# Out:
# 0.8720888888888889

# %%
from sklearn.tree import DecisionTreeClassifier
dtc = DecisionTreeClassifier()
dtc.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
dtc_y = svc.predict(x_test)

# %%
accuracy_score(y_test,dtc_y)
# Out:
# 0.8720888888888889
