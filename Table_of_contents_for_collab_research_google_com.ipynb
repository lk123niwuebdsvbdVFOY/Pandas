# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("/content/IPL.csv")
data
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
data.head(10)
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# 5   6    2017  Hyderabad  2017-04-09                Gujarat Lions
# 6   7    2017     Mumbai  2017-04-09        Kolkata Knight Riders
# 7   8    2017     Indore  2017-04-10  Royal Challengers Bangalore
# 8   9    2017       Pune  2017-04-11             Delhi Daredevils
# 9  10    2017     Mumbai  2017-04-12          Sunrisers Hyderabad
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# ...

# %%
data.tail(10)
# Out:
#       id  season           city        date                  team1  \
# 626  627    2016         Kanpur  2016-05-19  Kolkata Knight Riders
# 627  628    2016         Raipur  2016-05-20    Sunrisers Hyderabad
# 628  629    2016  Visakhapatnam  2016-05-21        Kings XI Punjab
# 629  630    2016         Kanpur  2016-05-21         Mumbai Indians
# 630  631    2016        Kolkata  2016-05-22  Kolkata Knight Riders
# 631  632    2016         Raipur  2016-05-22       Delhi Daredevils
# 632  633    2016      Bangalore  2016-05-24          Gujarat Lions
# 633  634    2016          Delhi  2016-05-25    Sunrisers Hyderabad
# 634  635    2016          Delhi  2016-05-27          Gujarat Lions
# 635  636    2016      Bangalore  2016-05-29    Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 626                Gujarat Lions                Gujarat Lions         field
# ...

# %%
data[data.columns].sum
# Out:
# <bound method DataFrame.sum of       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
data.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               636 non-null    int64
#  1   season           636 non-null    int64
#  2   city             629 non-null    object
#  3   date             636 non-null    object
#  4   team1            636 non-null    object
#  5   team2            636 non-null    object
#  6   toss_winner      636 non-null    object
#  7   toss_decision    636 non-null    object
#  8   result           636 non-null    object
#  9   dl_applied       636 non-null    int64
#  10  winner           633 non-null    object
#  11  win_by_runs      636 non-null    int64
#  12  win_by_wickets   636 non-null    int64
#  13  player_of_match  633 non-null    object
#  14  venue            636 non-null    object
#  15  umpire1          635 non-null    object
#  16  umpire2          635 non-null    object
# ...

# %%
data.describe()
# Out:
#                id       season  dl_applied  win_by_runs  win_by_wickets  \
# count  636.000000   636.000000  636.000000   636.000000      636.000000
# mean   318.500000  2012.490566    0.025157    13.682390        3.372642
# std    183.741666     2.773026    0.156726    23.908877        3.420338
# min      1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%    159.750000  2010.000000    0.000000     0.000000        0.000000
# 50%    318.500000  2012.000000    0.000000     0.000000        4.000000
# 75%    477.250000  2015.000000    0.000000    20.000000        7.000000
# max    636.000000  2017.000000    1.000000   146.000000       10.000000
#
#        umpire3
# count      0.0
# mean       NaN
# std        NaN
# min        NaN
# 25%        NaN
# 50%        NaN
# 75%        NaN
# max        NaN

# %%
data.isnull().sum()# iforgot here also
# Out:
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               3
# win_by_runs          0
# win_by_wickets       0
# player_of_match      3
# venue                0
# umpire1              1
# umpire2              1
# umpire3            636
# dtype: int64

# %%
data
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
data[['season','city','winner']] # here i write like data[] dindit given double brace
# Out:
#      season       city                       winner
# 0      2017  Hyderabad          Sunrisers Hyderabad
# 1      2017       Pune       Rising Pune Supergiant
# 2      2017     Rajkot        Kolkata Knight Riders
# 3      2017     Indore              Kings XI Punjab
# 4      2017  Bangalore  Royal Challengers Bangalore
# ..      ...        ...                          ...
# 631    2016     Raipur  Royal Challengers Bangalore
# 632    2016  Bangalore  Royal Challengers Bangalore
# 633    2016      Delhi          Sunrisers Hyderabad
# 634    2016      Delhi          Sunrisers Hyderabad
# 635    2016  Bangalore          Sunrisers Hyderabad
#
# [636 rows x 3 columns]

# %%
data.iloc[19:41]
# Out:
#     id  season        city        date                        team1  \
# 19  20    2017      Rajkot  2017-04-18  Royal Challengers Bangalore
# 20  21    2017   Hyderabad  2017-04-19          Sunrisers Hyderabad
# 21  22    2017      Indore  2017-04-20              Kings XI Punjab
# 22  23    2017     Kolkata  2017-04-21        Kolkata Knight Riders
# 23  24    2017      Mumbai  2017-04-22               Mumbai Indians
# 24  25    2017        Pune  2017-04-22          Sunrisers Hyderabad
# 25  26    2017      Rajkot  2017-04-23              Kings XI Punjab
# 26  27    2017     Kolkata  2017-04-23        Kolkata Knight Riders
# 27  28    2017      Mumbai  2017-04-24       Rising Pune Supergiant
# 28  29    2017        Pune  2017-04-26       Rising Pune Supergiant
# 29  30    2017   Bangalore  2017-04-27  Royal Challengers Bangalore
# 30  31    2017     Kolkata  2017-04-28             Delhi Daredevils
# 31  32    2017  Chandigarh  2017-04-28          Sunrisers Hyderabad
# ...

# %%
data
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
data[data.groupby('winner')]# i dont know this also
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_886/3365277591.py in <cell line: 0>()
# ----> 1 data[data.groupby('winner')]# i dont know this also
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4106             if is_iterator(key):
#    4107                 key = list(key)
# -> 4108             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4109
#    4110         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6193
#    6194         if self._index_as_unique:
# -> 6195             indexer = self.get_indexer_for(keyarr)
#    6196             keyarr = self.reindex(keyarr)[0]
#    6197         else:
#
# ...

# %%
data[data['season']==2017]
# Out:
#     id  season        city        date                        team1  \
# 0    1    2017   Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1    2    2017        Pune  2017-04-06               Mumbai Indians
# 2    3    2017      Rajkot  2017-04-07                Gujarat Lions
# 3    4    2017      Indore  2017-04-08       Rising Pune Supergiant
# 4    5    2017   Bangalore  2017-04-08  Royal Challengers Bangalore
# 5    6    2017   Hyderabad  2017-04-09                Gujarat Lions
# 6    7    2017      Mumbai  2017-04-09        Kolkata Knight Riders
# 7    8    2017      Indore  2017-04-10  Royal Challengers Bangalore
# 8    9    2017        Pune  2017-04-11             Delhi Daredevils
# 9   10    2017      Mumbai  2017-04-12          Sunrisers Hyderabad
# 10  11    2017     Kolkata  2017-04-13              Kings XI Punjab
# 11  12    2017   Bangalore  2017-04-14  Royal Challengers Bangalore
# 12  13    2017      Rajkot  2017-04-14       Rising Pune Supergiant
# ...

# %%
data[data['team1']== "Mumbai Indians"]
# Out:
#       id  season           city        date           team1  \
# 1      2    2017           Pune  2017-04-06  Mumbai Indians
# 23    24    2017         Mumbai  2017-04-22  Mumbai Indians
# 43    44    2017          Delhi  2017-05-06  Mumbai Indians
# 46    47    2017      Hyderabad  2017-05-08  Mumbai Indians
# 52    53    2017        Kolkata  2017-05-13  Mumbai Indians
# ..   ...     ...            ...         ...             ...
# 587  588    2016      Hyderabad  2016-04-18  Mumbai Indians
# 596  597    2016     Chandigarh  2016-04-25  Mumbai Indians
# 618  619    2016  Visakhapatnam  2016-05-13  Mumbai Indians
# 622  623    2016  Visakhapatnam  2016-05-15  Mumbai Indians
# 629  630    2016         Kanpur  2016-05-21  Mumbai Indians
#
#                       team2             toss_winner toss_decision  result  \
# 1    Rising Pune Supergiant  Rising Pune Supergiant         field  normal
# 23         Delhi Daredevils        Delhi Daredevils         field  normal
# ...

# %%
data[(data['team1']== "Mumbai Indians") & (data['city'] == "Mumbai")] # here i writen like data[data['team1']== "Mumbai Indians" and data['city'] == "Mumbai"]
# Out:
#       id  season    city        date           team1  \
# 23    24    2017  Mumbai  2017-04-22  Mumbai Indians
# 62    63    2008  Mumbai  2008-04-20  Mumbai Indians
# 71    72    2008  Mumbai  2008-04-27  Mumbai Indians
# 81    82    2008  Mumbai  2008-05-04  Mumbai Indians
# 175  176    2010  Mumbai  2010-03-13  Mumbai Indians
# 187  188    2010  Mumbai  2010-03-20  Mumbai Indians
# 198  199    2010  Mumbai  2010-03-28  Mumbai Indians
# 206  207    2010  Mumbai  2010-04-03  Mumbai Indians
# 220  221    2010  Mumbai  2010-04-13  Mumbai Indians
# 230  231    2010  Mumbai  2010-04-21  Mumbai Indians
# 246  247    2011  Mumbai  2011-04-15  Mumbai Indians
# 256  257    2011  Mumbai  2011-04-22  Mumbai Indians
# 272  273    2011  Mumbai  2011-05-02  Mumbai Indians
# 276  277    2011  Mumbai  2011-05-04  Mumbai Indians
# 281  282    2011  Mumbai  2011-05-07  Mumbai Indians
# 298  299    2011  Mumbai  2011-05-20  Mumbai Indians
# 318  319    2012  Mumbai  2012-04-11  Mumbai Indians
# ...

# %%
data[(data['winner']=="Chennai Super Kings") | (data['winner'] == "Mumbai Indians")]
# Out:
#       id  season           city        date                        team1  \
# 6      7    2017         Mumbai  2017-04-09        Kolkata Knight Riders
# 9     10    2017         Mumbai  2017-04-12          Sunrisers Hyderabad
# 11    12    2017      Bangalore  2017-04-14  Royal Challengers Bangalore
# 15    16    2017         Mumbai  2017-04-16                Gujarat Lions
# 21    22    2017         Indore  2017-04-20              Kings XI Punjab
# ..   ...     ...            ...         ...                          ...
# 596  597    2016     Chandigarh  2016-04-25               Mumbai Indians
# 599  600    2016         Mumbai  2016-04-28        Kolkata Knight Riders
# 604  605    2016           Pune  2016-05-01      Rising Pune Supergiants
# 616  617    2016      Bangalore  2016-05-11  Royal Challengers Bangalore
# 622  623    2016  Visakhapatnam  2016-05-15               Mumbai Indians
#
#                 team2       toss_winner toss_decision  result  dl_applied  \
# ...

# %%
data.sort_values('season')
# Out:
#     id  season        city        date                   team1  \
# 63  64    2008     Kolkata  2008-04-20         Deccan Chargers
# 60  61    2008  Chandigarh  2008-04-19     Chennai Super Kings
# 61  62    2008       Delhi  2008-04-19        Rajasthan Royals
# 59  60    2008   Bangalore  2008-04-18   Kolkata Knight Riders
# 62  63    2008      Mumbai  2008-04-20          Mumbai Indians
# ..  ..     ...         ...         ...                     ...
# 27  28    2017      Mumbai  2017-04-24  Rising Pune Supergiant
# 28  29    2017        Pune  2017-04-26  Rising Pune Supergiant
# 17  18    2017       Delhi  2017-04-17        Delhi Daredevils
# 16  17    2017   Bangalore  2017-04-16  Rising Pune Supergiant
# 0    1    2017   Hyderabad  2017-04-05     Sunrisers Hyderabad
#
#                           team2                  toss_winner toss_decision  \
# 63        Kolkata Knight Riders              Deccan Chargers           bat
# ...

# %%
data.sort_values("season",ascending= False )
# Out:
#     id  season        city        date                        team1  \
# 0    1    2017   Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1    2    2017        Pune  2017-04-06               Mumbai Indians
# 3    4    2017      Indore  2017-04-08       Rising Pune Supergiant
# 2    3    2017      Rajkot  2017-04-07                Gujarat Lions
# 4    5    2017   Bangalore  2017-04-08  Royal Challengers Bangalore
# ..  ..     ...         ...         ...                          ...
# 72  73    2008  Chandigarh  2008-04-27             Delhi Daredevils
# 73  74    2008   Bangalore  2008-04-28          Chennai Super Kings
# 74  75    2008     Kolkata  2008-04-29        Kolkata Knight Riders
# 75  76    2008       Delhi  2008-04-30             Delhi Daredevils
# 59  60    2008   Bangalore  2008-04-18        Kolkata Knight Riders
#
#                           team2                  toss_winner toss_decision  \
# ...

# %%
data.sort_values(["season" , "city"]) # here i writeen like data.sort_values(data["season" , "city"])
# Out:
#     id  season       city        date                        team1  \
# 59  60    2008  Bangalore  2008-04-18        Kolkata Knight Riders
# 69  70    2008  Bangalore  2008-04-26  Royal Challengers Bangalore
# 73  74    2008  Bangalore  2008-04-28          Chennai Super Kings
# 83  84    2008  Bangalore  2008-05-05  Royal Challengers Bangalore
# 89  90    2008  Bangalore  2008-05-28  Royal Challengers Bangalore
# ..  ..     ...        ...         ...                          ...
# 2    3    2017     Rajkot  2017-04-07                Gujarat Lions
# 12  13    2017     Rajkot  2017-04-14       Rising Pune Supergiant
# 19  20    2017     Rajkot  2017-04-18  Royal Challengers Bangalore
# 25  26    2017     Rajkot  2017-04-23              Kings XI Punjab
# 33  34    2017     Rajkot  2017-04-29                Gujarat Lions
#
#                           team2                  toss_winner toss_decision  \
# 59  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# ...

# %%
data['Match_No'] = 1

# %%
data['Match_No']
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 631    1
# 632    1
# 633    1
# 634    1
# 635    1
# Name: Match_No, Length: 636, dtype: int64

# %%
data.dropna()
# Out:
# Empty DataFrame
# Columns: [id, season, city, date, team1, team2, toss_winner, toss_decision, result, dl_applied, winner, win_by_runs, win_by_wickets, player_of_match, venue, umpire1, umpire2, umpire3, Match_No]
# Index: []

# %%
data.dropna().count()
# Out:
# id                 0
# season             0
# city               0
# date               0
# team1              0
# team2              0
# toss_winner        0
# toss_decision      0
# result             0
# dl_applied         0
# winner             0
# win_by_runs        0
# win_by_wickets     0
# player_of_match    0
# venue              0
# umpire1            0
# umpire2            0
# umpire3            0
# Match_No           0
# dtype: int64

# %%
data.fillna(0)
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
data['Match_No'] = data['Match_No'].between(1,636)

# %%
data[data['Match_No']]
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
data.groupby('season')

# %%
data.value_counts('city')
# Out:
# city
# Mumbai            85
# Bangalore         66
# Kolkata           61
# Delhi             60
# Hyderabad         49
# Chennai           48
# Chandigarh        46
# Jaipur            33
# Pune              32
# Durban            15
# Ahmedabad         12
# Centurion         12
# Visakhapatnam     11
# Rajkot            10
# Dharamsala         9
# Johannesburg       8
# Ranchi             7
# Cuttack            7
# Abu Dhabi          7
# Port Elizabeth     7
# Cape Town          7
# Raipur             6
# Sharjah            6
# Kochi              5
# Indore             5
# Kanpur             4
# Kimberley          3
# East London        3
# Nagpur             3
# Bloemfontein       2
# Name: count, dtype: int64

# %%
data.value_counts('toss_winner')
# Out:
# toss_winner
# Mumbai Indians                 85
# Kolkata Knight Riders          78
# Delhi Daredevils               72
# Royal Challengers Bangalore    70
# Kings XI Punjab                68
# Chennai Super Kings            66
# Rajasthan Royals               63
# Deccan Chargers                43
# Sunrisers Hyderabad            35
# Pune Warriors                  20
# Gujarat Lions                  15
# Kochi Tuskers Kerala            8
# Rising Pune Supergiants         7
# Rising Pune Supergiant          6
# Name: count, dtype: int64

# %%
data.value_counts('winner')
# Out:
# winner
# Mumbai Indians                 92
# Chennai Super Kings            79
# Kolkata Knight Riders          77
# Royal Challengers Bangalore    73
# Kings XI Punjab                70
# Rajasthan Royals               63
# Delhi Daredevils               62
# Sunrisers Hyderabad            42
# Deccan Chargers                29
# Gujarat Lions                  13
# Pune Warriors                  12
# Rising Pune Supergiant         10
# Kochi Tuskers Kerala            6
# Rising Pune Supergiants         5
# Name: count, dtype: int64

# %%
data.value_counts('dl_applied')
# Out:
# dl_applied
# 0    620
# 1     16
# Name: count, dtype: int64

# %%
data[data['team1']== "Mumbai Indians"]
# Out:
#       id  season           city        date           team1  \
# 1      2    2017           Pune  2017-04-06  Mumbai Indians
# 23    24    2017         Mumbai  2017-04-22  Mumbai Indians
# 43    44    2017          Delhi  2017-05-06  Mumbai Indians
# 46    47    2017      Hyderabad  2017-05-08  Mumbai Indians
# 52    53    2017        Kolkata  2017-05-13  Mumbai Indians
# ..   ...     ...            ...         ...             ...
# 587  588    2016      Hyderabad  2016-04-18  Mumbai Indians
# 596  597    2016     Chandigarh  2016-04-25  Mumbai Indians
# 618  619    2016  Visakhapatnam  2016-05-13  Mumbai Indians
# 622  623    2016  Visakhapatnam  2016-05-15  Mumbai Indians
# 629  630    2016         Kanpur  2016-05-21  Mumbai Indians
#
#                       team2             toss_winner toss_decision  result  \
# 1    Rising Pune Supergiant  Rising Pune Supergiant         field  normal
# 23         Delhi Daredevils        Delhi Daredevils         field  normal
# ...

# %%
data.value_counts('city')
# Out:
# city
# Mumbai            85
# Bangalore         66
# Kolkata           61
# Delhi             60
# Hyderabad         49
# Chennai           48
# Chandigarh        46
# Jaipur            33
# Pune              32
# Durban            15
# Ahmedabad         12
# Centurion         12
# Visakhapatnam     11
# Rajkot            10
# Dharamsala         9
# Johannesburg       8
# Ranchi             7
# Cuttack            7
# Abu Dhabi          7
# Port Elizabeth     7
# Cape Town          7
# Raipur             6
# Sharjah            6
# Kochi              5
# Indore             5
# Kanpur             4
# Kimberley          3
# East London        3
# Nagpur             3
# Bloemfontein       2
# Name: count, dtype: int64

# %%
data[(data.value_counts('city')).head(5)]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_886/587946312.py in <cell line: 0>()
# ----> 1 data[(data.value_counts('city')).head(5)]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4106             if is_iterator(key):
#    4107                 key = list(key)
# -> 4108             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4109
#    4110         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6198             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6199
# -> 6200         self._raise_if_missing(keyarr, indexer, axis_name)
#    6201
#    6202         keyarr = self.take(indexer)
#
# ...
