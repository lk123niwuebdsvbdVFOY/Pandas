# %% [markdown]
# <a href="https://colab.research.google.com/github/lk123niwuebdsvbdVFOY/Pandas/blob/AI/svc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('/content/wine_quality_classification.csv')
data
# Out:
#      fixed_acidity  residual_sugar  alcohol  density quality_label
# 0              9.3             6.4     13.6   1.0005          high
# 1             11.2             2.0     14.0   0.9912        medium
# 2             11.6             0.9      8.2   0.9935           low
# 3             12.9             6.6     12.7   1.0002           low
# 4             13.9            13.8     10.4   0.9942        medium
# ..             ...             ...      ...      ...           ...
# 995           13.0             4.3     13.1   1.0035           low
# 996            6.4             5.3      9.5   1.0040           low
# 997            4.5             9.0     13.8   0.9931        medium
# 998            5.3            12.2      8.1   0.9955           low
# 999            7.6            14.3     10.1   0.9924          high
#
# [1000 rows x 5 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   fixed_acidity   1000 non-null   float64
#  1   residual_sugar  1000 non-null   float64
#  2   alcohol         1000 non-null   float64
#  3   density         1000 non-null   float64
#  4   quality_label   1000 non-null   object
# dtypes: float64(4), object(1)
# memory usage: 39.2+ KB

# %%
data.describe()
# Out:
#        fixed_acidity  residual_sugar      alcohol      density
# count    1000.000000      1000.00000  1000.000000  1000.000000
# mean       10.174300         7.69200    11.039900     0.997505
# std         3.452693         4.20892     1.760283     0.004300
# min         4.000000         0.50000     8.000000     0.990000
# 25%         7.100000         4.10000     9.500000     0.993900
# 50%        10.400000         7.55000    11.000000     0.997400
# 75%        13.125000        11.50000    12.600000     1.001200
# max        16.000000        15.00000    14.000000     1.005000

# %%
data.isnull().sum()
# Out:
# fixed_acidity     0
# residual_sugar    0
# alcohol           0
# density           0
# quality_label     0
# dtype: int64

# %%
data.head(1)
# Out:
#    fixed_acidity  residual_sugar  alcohol  density quality_label
# 0            9.3             6.4     13.6   1.0005          high

# %%
sns.boxplot(x='fixed_acidity',hue='quality_label',data=data)
plt.show()

# %%
sns.scatterplot(x="alcohol", y="density", hue="quality_label",data=data)
plt.show()

# %%
sns.scatterplot(x="alcohol", y="fixed_acidity", hue="quality_label",data=data)
plt.show()

# %%
data.columns
# Out:
# Index(['fixed_acidity', 'residual_sugar', 'alcohol', 'density',
#        'quality_label'],
#       dtype='object')

# %%
x = data[['fixed_acidity', 'residual_sugar', 'alcohol', 'density']]
y = data['quality_label']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25)

# %%
from sklearn.svm import SVC
svc = SVC(kernel='rbf')
svc.fit(x_train,y_train)
# Out:
# SVC()

# %%
svc_y = svc.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
print('R2',metrics.accuracy_score(y_test,svc_y))
# Out:
# R2 0.404
