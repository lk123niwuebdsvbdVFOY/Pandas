# %% [markdown]
# <a href="https://colab.research.google.com/github/lk123niwuebdsvbdVFOY/Pandas/blob/AI/all.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('/content/Student_Performance.csv')
data
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7               99                        Yes            9
# 1                 4               82                         No            4
# 2                 8               51                        Yes            7
# 3                 5               52                        Yes            5
# 4                 7               75                         No            8
# ...             ...              ...                        ...          ...
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
#       Sample Question Papers Practiced  Performance Index
# 0                                    1               91.0
# 1                                    2               65.0
# 2                                    2               45.0
# 3                                    2               36.0
# 4                                    5               66.0
# ...                                ...                ...
# 9995                                 2               23.0
# 9996                                 5               58.0
# 9997                                 5               74.0
# 9998                                 0               95.0
# 9999                                 1               64.0
#
# [10000 rows x 6 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Hours Studied                     10000 non-null  int64
#  1   Previous Scores                   10000 non-null  int64
#  2   Extracurricular Activities        10000 non-null  object
#  3   Sleep Hours                       10000 non-null  int64
#  4   Sample Question Papers Practiced  10000 non-null  int64
#  5   Performance Index                 10000 non-null  float64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 468.9+ KB

# %%
data.describe()
# Out:
#        Hours Studied  Previous Scores   Sleep Hours  \
# count   10000.000000     10000.000000  10000.000000
# mean        4.992900        69.445700      6.530600
# std         2.589309        17.343152      1.695863
# min         1.000000        40.000000      4.000000
# 25%         3.000000        54.000000      5.000000
# 50%         5.000000        69.000000      7.000000
# 75%         7.000000        85.000000      8.000000
# max         9.000000        99.000000      9.000000
#
#        Sample Question Papers Practiced  Performance Index
# count                      10000.000000       10000.000000
# mean                           4.583300          55.224800
# std                            2.867348          19.212558
# min                            0.000000          10.000000
# 25%                            2.000000          40.000000
# 50%                            5.000000          55.000000
# 75%                            7.000000          71.000000
# max                            9.000000         100.000000

# %%
data.isnull().sum()
# Out:
# Hours Studied                       0
# Previous Scores                     0
# Extracurricular Activities          0
# Sleep Hours                         0
# Sample Question Papers Practiced    0
# Performance Index                   0
# dtype: int64

# %%
data.head(2)
# Out:
#    Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0              7               99                        Yes            9
# 1              4               82                         No            4
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1               91.0
# 1                                 2               65.0

# %%
sns.boxplot(x='Hours Studied',y='Performance Index',data = data)
plt.xlabel("Hours Studied")
plt.ylabel("Performance Index")
plt.title('Hours Studied vs Performance Index')
plt.grid()

# %%
sns.scatterplot(x='Previous Scores',y='Performance Index',data = data)
plt.xlabel("Previous Scores")
plt.ylabel("Performance Index")
plt.title('Previous Scores vs Performance Index')
plt.grid()

# %%
sns.boxplot(x='Extracurricular Activities',y='Performance Index',data = data)
plt.xlabel("Extracurricular Activities")
plt.ylabel("Performance Index")
plt.title('Extracurricular Activities vs Performance Index')
plt.grid()

# %%
sns.scatterplot(x='Sleep Hours',y='Performance Index',data = data)
plt.xlabel("Sleep Hours")
plt.ylabel("Performance Index")
plt.title('Sleep Hours vs Performance Index')
plt.grid()

# %%
sns.scatterplot(x='Sample Question Papers Practiced',y='Performance Index',data = data)
plt.xlabel("Sample Question Papers Practiced")
plt.ylabel("Performance Index")
plt.title('Sample Question Papers Practiced vs Performance Index')
plt.grid()

# %%
data.head(2)
# Out:
#    Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0              7               99                        Yes            9
# 1              4               82                         No            4
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1               91.0
# 1                                 2               65.0

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data['Extracurricular Activities'] = le.fit_transform(data['Extracurricular Activities'])

# %%
data.head(2)
# Out:
#    Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 0              7               99                           1            9
# 1              4               82                           0            4
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1               91.0
# 1                                 2               65.0

# %%
data.columns
# Out:
# Index(['Hours Studied', 'Previous Scores', 'Extracurricular Activities',
#        'Sleep Hours', 'Sample Question Papers Practiced', 'Performance Index'],
#       dtype='object')

# %%
x = data[['Hours Studied', 'Previous Scores', 'Extracurricular Activities','Sleep Hours', 'Sample Question Papers Practiced']]
y = data['Performance Index']

# %%
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures()
x = poly.fit_transform(x)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.25, random_state=25)

# %%
x_train.shape
# Out:
# (7500, 21)

# %%
x_test.shape
# Out:
# (2500, 21)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred = lr.predict(x_test)

# %%
from sklearn import metrics
print("Mae:",metrics.mean_absolute_error(y_test,pred))
print("Mse:",metrics.mean_squared_error(y_test,pred))
print("Rmse:",np.sqrt(metrics.mean_squared_error(y_test,pred)))
print("R2:",metrics.r2_score(y_test,pred))
# Out:
# Mae: 1.6179515792145462
# Mse: 4.145906540395821
# Rmse: 2.03614993072608
# R2: 0.9886873870807811

# %%
from sklearn import metrics
print("Mae:",metrics.mean_absolute_error(y_test,pred))
print("Mse:",metrics.mean_squared_error(y_test,pred))
print("Rmse:",np.sqrt(metrics.mean_squared_error(y_test,pred)))
print("R2:",metrics.r2_score(y_test,pred))
# Out:
# Mae: 2.432866666666667
# Mse: 9.607788888888889
# Rmse: 3.099643348659469
# R2: 0.9737839732636145

# %%
from sklearn import metrics
print("Mae:",metrics.mean_absolute_error(y_test,pred))
print("Mse:",metrics.mean_squared_error(y_test,pred))
print("Rmse:",np.sqrt(metrics.mean_squared_error(y_test,pred)))
print("R2:",metrics.r2_score(y_test,pred))
# Out:
# Mae: 1.6385418502258982
# Mse: 4.223049644217262
# Rmse: 2.05500599615117
# R2: 0.9887971569208617
